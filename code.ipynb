# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("test_data.csv")

# %%
data.insert(0, 'gender_id', 0)

# %%
for i in range(len(data)):
    if data.loc[i+1, 'Gender_ID'] == 'Male':
        data.loc[i+1, 'gender_id'] = '1'
    elif data.loc[i+1, 'Gender_ID'] != 'Female':
        data.drop(i+1)

# %%
Const = data['Constipation(3)'].groupby([data['drug_con'], data['Constipation(3)']]).count()
Const
# Out:
# drug_con  Constipation(3)
# 0         0                  5904
#           1                   235
# 1         0                  2921
#           1                  1495
# Name: Constipation(3), dtype: int64

# %%
Agr = data['Agranulocytosis(2)'].groupby([data['drug_con'], data['Agranulocytosis(2)']]).count()
Agr
# Out:
# drug_con  Agranulocytosis(2)
# 0         0                     6133
#           1                        6
# 1         0                     4278
#           1                      138
# Name: Agranulocytosis(2), dtype: int64

# %%
Hyp = data['Hypersalivation(1)'].groupby([data['drug_con'], data['Hypersalivation(1)']]).count()
Hyp
# Out:
# drug_con  Hypersalivation(1)
# 0         0                     6095
#           1                       44
# 1         0                     3169
#           1                     1247
# Name: Hypersalivation(1), dtype: int64

# %%
Noc = data['Nocturnal enuresis(2)'].groupby([data['drug_con'], data['Nocturnal enuresis(2)']]).count()
Noc
# Out:
# drug_con  Nocturnal enuresis(2)
# 0         0                        6047
#           1                          92
# 1         0                        3788
#           1                         628
# Name: Nocturnal enuresis(2), dtype: int64

# %%
Pne = data['Pneumonia(7)'].groupby([data['drug_con'], data['Pneumonia(7)']]).count()
Pne
# Out:
# drug_con  Pneumonia(7)
# 0         0               6072
#           1                 67
# 1         0               4149
#           1                267
# Name: Pneumonia(7), dtype: int64

# %%
Sei = data['Seizures(9)'].groupby([data['drug_con'], data['Seizures(9)']]).count()
Sei
# Out:
# drug_con  Seizures(9)
# 0         0              5270
#           1               869
# 1         0              1554
#           1              2862
# Name: Seizures(9), dtype: int64

# %%
Ven = data['Venous thromboembolism(4)'].groupby([data['drug_con'], data['Venous thromboembolism(4)']]).count()
Ven
# Out:
# drug_con  Venous thromboembolism(4)
# 0         0                            6130
#           1                               9
# 1         0                            4378
#           1                              38
# Name: Venous thromboembolism(4), dtype: int64

# %%
Wei = data['Weight gain(1)'].groupby([data['drug_con'], data['Weight gain(1)']]).count()
Wei
# Out:
# drug_con  Weight gain(1)
# 0         0                 5795
#           1                  344
# 1         0                 2287
#           1                 2129
# Name: Weight gain(1), dtype: int64

# %%
withoutmed = [0.98, 38.28, 7.17, 14.99, 10.91, 141.55, 1.47, 56.04]
withmed = [31.25, 338.54, 282.38, 142.21, 60.46, 648.1, 8.6, 482.11]
x = ['Agr', 'Const', 'Hyp', 'Noc', 'Pne', 'Sei', 'Ven', 'Wei']

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
for i in range(len(withoutmed)):
    plt.bar(1, withoutmed[i],width = 0.1,facecolor = 'lightskyblue',edgecolor = 'white')
    plt.bar(1.35, withmed[i],width = 0.1,facecolor = 'yellowgreen',edgecolor = 'white')
    plt.title(x[i])
    plt.show()

# %%
Wei2 = data['Weight gain(1)'].groupby([data['ethnicitycleaned'], data['Weight gain(1)']]).count()
Wei2
# Out:
# ethnicitycleaned                Weight gain(1)
# African (N)                     0                  373
#                                 1                  320
# Any other Asian background (L)  0                  135
#                                 1                   53
# Any other black background (P)  0                  507
#                                 1                  393
# Any other ethnic group (S)      0                  361
#                                 1                   79
# Any other mixed background (G)  0                   48
#                                 1                   23
# Any other white background (C)  0                  421
#                                 1                  128
# Bangladeshi (K)                 0                   26
#                                 1                   10
# British (A)                     0                 2670
#                                 1                  899
# ...

# %%
data_sel = data[['Agranulocytosis(2)', 'Constipation(3)', 'Hypersalivation(1)', 'Nocturnal enuresis(2)', 'Pneumonia(7)', 'Seizures(9)', 'Venous thromboembolism(4)', 'Weight gain(1)', 'drug_con', 'age', 'gender_id', 'Gender_ID', 'ethnicitycleaned']]

# %%
data_sel = data_sel.dropna()

# %%
for i in data_sel.index:
    if data_sel.loc[i, 'ethnicitycleaned'] == 'Not Stated (Z)':
        data_sel.loc[i, 'ethnicitycleaned'] = np.nan
data_sel = data_sel.dropna()
data_sel
# Out:
#        Agranulocytosis(2)  Constipation(3)  Hypersalivation(1)  \
# brcid
# 4                       0                0                   0
# 5                       0                0                   0
# 6                       0                0                   0
# 7                       0                1                   0
# 10                      0                0                   0
# 11                      0                0                   0
# 13                      0                0                   0
# 15                      0                0                   0
# 16                      0                0                   0
# 17                      0                0                   0
# 20                      0                0                   0
# 21                      0                0                   0
# 23                      0                0                   0
# 26                      0                0                   0
# ...

# %%
data_sel['Weight gain(1)'].groupby([data_sel['ethnicitycleaned'], data_sel['Weight gain(1)']]).count()
# Out:
# ethnicitycleaned                Weight gain(1)
# African (N)                     0                  373
#                                 1                  320
# Any other Asian background (L)  0                  135
#                                 1                   53
# Any other black background (P)  0                  507
#                                 1                  393
# Any other ethnic group (S)      0                  361
#                                 1                   79
# Any other mixed background (G)  0                   48
#                                 1                   23
# Any other white background (C)  0                  421
#                                 1                  128
# Bangladeshi (K)                 0                   26
#                                 1                   10
# British (A)                     0                 2670
#                                 1                  899
# ...

# %%
data_sel.to_csv('D:\data1.csv', sep=',')

# %%
data_m = data_sel

# %%
data_m.insert(0, 'age_period', 0)

# %%
for i in data_m.index:
    if data_m.loc[i, 'age'] == '#VALUE!':
        data_m.loc[i, 'age'] = np.nan
data_m = data_m.dropna()

# %%
for i in data_m.index:
    if int(data_m.loc[i, 'age']) <= 25:
        data_m.loc[i, 'age_period'] = 'teen'
    elif int(data_m.loc[i, 'age']) <= 50:
        data_m.loc[i, 'age_period'] = 'mid_age'
    else:
        data_m.loc[i, 'age_period'] = 'elder'

# %%
time_window = pd.read_csv("time_window_cleaned.csv")
# Out:
# d:\anaconda.1\lib\site-packages\IPython\core\interactiveshell.py:2717: DtypeWarning: Columns (16) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
time_window = time_window.dropna()

# %%
time_window.insert(0, 'wg_pre', 0)

# %%
time_window.insert(0, 'gender_id', 0)

# %%
for i in time_window.index:
    if time_window.loc[i, 'Gender_ID'] == 'Male':
        time_window.loc[i, 'gender_id'] = '1'

# %%
for i in time_window.index:
    if time_window.loc[i, 'age'] == '#NUM!':
        time_window.loc[i, 'age'] = np.nan
time_window = time_window.dropna()

# %%
for i in time_window.index:
    if time_window.loc[i, 'ethnicitycleaned'] in ['Not Stated (Z)', '\N']:
        time_window.loc[i, 'ethnicitycleaned'] = np.nan
time_window = time_window.dropna()

# %%
time_window.insert(0,'age_period',0)

# %%
for i in time_window.index:
    if int(time_window.loc[i, 'age']) <= 25:
        time_window.loc[i, 'age_period'] = 'teen'
    elif int(time_window.loc[i, 'age']) <= 50:
        time_window.loc[i, 'age_period'] = 'mid_age'
    else:
        time_window.loc[i, 'age_period'] = 'elder'

# %%
a = 0
for i in time_window.index:
    if time_window.loc[i, 'ethnicitycleaned'] in ['White and Asian (F)', 'White and Black African (E)', 'White and black Caribbean (D)']:
        if time_window.loc[i, 'age_period'] == 'teen':
            a = 2.415*int(time_window.loc[i, 'drug_con']) - 0.489*int(time_window.loc[i, 'gender_id']) - 2.655
            if a <= 0:
                time_window.loc[i, 'wg_pre'] = 0
            else:
                time_window.loc[i, 'wg_pre'] = 1
        elif time_window.loc[i, 'age_period'] == 'mid_age':
            a = 2.415*int(time_window.loc[i, 'drug_con']) - 0.489*int(time_window.loc[i, 'gender_id']) - 2.655 + 0.924
            if a <= 0:
                time_window.loc[i, 'wg_pre'] = 0
            else:
                time_window.loc[i, 'wg_pre'] = 1
        else:
            a = 2.415*int(time_window.loc[i, 'drug_con']) - 0.489*int(time_window.loc[i, 'gender_id']) - 2.655 + 0.552
            if a <= 0:
                time_window.loc[i, 'wg_pre'] = 0
            else:
                time_window.loc[i, 'wg_pre'] = 1
    elif time_window.loc[i, 'ethnicitycleaned'] == 'African (N)':
        if time_window.loc[i, 'age_period'] == 'teen':
            a = 2.415*int(time_window.loc[i, 'drug_con']) - 0.489*int(time_window.loc[i, 'gender_id']) - 2.655 + 0.187
            if a <= 0:
                time_window.loc[i, 'wg_pre'] = 0
            else:
                time_window.loc[i, 'wg_pre'] = 1
        elif time_window.loc[i, 'age_period'] == 'mid_age':
            a = 2.415*int(time_window.loc[i, 'drug_con']) - 0.489*int(time_window.loc[i, 'gender_id']) - 2.655 + 0.924 + 0.187
            if a <= 0:
                time_window.loc[i, 'wg_pre'] = 0
            else:
                time_window.loc[i, 'wg_pre'] = 1
        else:
            a = 2.415*int(time_window.loc[i, 'drug_con']) - 0.489*int(time_window.loc[i, 'gender_id']) - 2.655 + 0.552 + 0.187
            if a <= 0:
                time_window.loc[i, 'wg_pre'] = 0
            else:
                time_window.loc[i, 'wg_pre'] = 1
    elif time_window.loc[i, 'ethnicitycleaned'] == 'Bangladeshi (K)':
        if time_window.loc[i, 'age_period'] == 'teen':
            a = 2.415*int(time_window.loc[i, 'drug_con']) - 0.489*int(time_window.loc[i, 'gender_id']) - 2.655 - 0.261
            if a <= 0:
                time_window.loc[i, 'wg_pre'] = 0
            else:
                time_window.loc[i, 'wg_pre'] = 1
        elif time_window.loc[i, 'age_period'] == 'mid_age':
            a = 2.415*int(time_window.loc[i, 'drug_con']) - 0.489*int(time_window.loc[i, 'gender_id']) - 2.655 + 0.924 - 0.261
            if a <= 0:
                time_window.loc[i, 'wg_pre'] = 0
            else:
                time_window.loc[i, 'wg_pre'] = 1
        else:
            a = 2.415*int(time_window.loc[i, 'drug_con']) - 0.489*int(time_window.loc[i, 'gender_id']) - 2.655 + 0.552 - 0.261
            if a <= 0:
                time_window.loc[i, 'wg_pre'] = 0
            else:
                time_window.loc[i, 'wg_pre'] = 1
    elif time_window.loc[i, 'ethnicitycleaned'] == 'British (A)':
        if time_window.loc[i, 'age_period'] == 'teen':
            a = 2.415*int(time_window.loc[i, 'drug_con']) - 0.489*int(time_window.loc[i, 'gender_id']) - 2.655 - 0.399
            if a <= 0:
                time_window.loc[i, 'wg_pre'] = 0
            else:
                time_window.loc[i, 'wg_pre'] = 1
        elif time_window.loc[i, 'age_period'] == 'mid_age':
            a = 2.415*int(time_window.loc[i, 'drug_con']) - 0.489*int(time_window.loc[i, 'gender_id']) - 2.655 + 0.924 - 0.399
            if a <= 0:
                time_window.loc[i, 'wg_pre'] = 0
            else:
                time_window.loc[i, 'wg_pre'] = 1
        else:
            a = 2.415*int(time_window.loc[i, 'drug_con']) - 0.489*int(time_window.loc[i, 'gender_id']) - 2.655 + 0.552 - 0.399
            if a <= 0:
                time_window.loc[i, 'wg_pre'] = 0
            else:
                time_window.loc[i, 'wg_pre'] = 1
    elif time_window.loc[i, 'ethnicitycleaned'] == 'Caribbean (M)':
        if time_window.loc[i, 'age_period'] == 'teen':
            a = 2.415*int(time_window.loc[i, 'drug_con']) - 0.489*int(time_window.loc[i, 'gender_id']) - 2.655 + 0.191
            if a <= 0:
                time_window.loc[i, 'wg_pre'] = 0
            else:
                time_window.loc[i, 'wg_pre'] = 1
        elif time_window.loc[i, 'age_period'] == 'mid_age':
            a = 2.415*int(time_window.loc[i, 'drug_con']) - 0.489*int(time_window.loc[i, 'gender_id']) - 2.655 + 0.924 + 0.191
            if a <= 0:
                time_window.loc[i, 'wg_pre'] = 0
            else:
                time_window.loc[i, 'wg_pre'] = 1
        else:
            a = 2.415*int(time_window.loc[i, 'drug_con']) - 0.489*int(time_window.loc[i, 'gender_id']) - 2.655 + 0.552 + 0.191
            if a <= 0:
                time_window.loc[i, 'wg_pre'] = 0
            else:
                time_window.loc[i, 'wg_pre'] = 1
    elif time_window.loc[i, 'ethnicitycleaned'] == 'Chinese (R)':
        if time_window.loc[i, 'age_period'] == 'teen':
            a = 2.415*int(time_window.loc[i, 'drug_con']) - 0.489*int(time_window.loc[i, 'gender_id']) - 2.655 + 0.179
            if a <= 0:
                time_window.loc[i, 'wg_pre'] = 0
            else:
                time_window.loc[i, 'wg_pre'] = 1
        elif time_window.loc[i, 'age_period'] == 'mid_age':
            a = 2.415*int(time_window.loc[i, 'drug_con']) - 0.489*int(time_window.loc[i, 'gender_id']) - 2.655 + 0.924 + 0.179
            if a <= 0:
                time_window.loc[i, 'wg_pre'] = 0
            else:
                time_window.loc[i, 'wg_pre'] = 1
        else:
            a = 2.415*int(time_window.loc[i, 'drug_con']) - 0.489*int(time_window.loc[i, 'gender_id']) - 2.655 + 0.552 + 0.179
            if a <= 0:
                time_window.loc[i, 'wg_pre'] = 0
            else:
                time_window.loc[i, 'wg_pre'] = 1
    elif time_window.loc[i, 'ethnicitycleaned'] == 'Indian (H)':
        if time_window.loc[i, 'age_period'] == 'teen':
            a = 2.415*int(time_window.loc[i, 'drug_con']) - 0.489*int(time_window.loc[i, 'gender_id']) - 2.655 - 0.520
            if a <= 0:
                time_window.loc[i, 'wg_pre'] = 0
            else:
                time_window.loc[i, 'wg_pre'] = 1
        elif time_window.loc[i, 'age_period'] == 'mid_age':
            a = 2.415*int(time_window.loc[i, 'drug_con']) - 0.489*int(time_window.loc[i, 'gender_id']) - 2.655 + 0.924 - 0.520
            if a <= 0:
                time_window.loc[i, 'wg_pre'] = 0
            else:
                time_window.loc[i, 'wg_pre'] = 1
        else:
            a = 2.415*int(time_window.loc[i, 'drug_con']) - 0.489*int(time_window.loc[i, 'gender_id']) - 2.655 + 0.552 - 0.520
            if a <= 0:
                time_window.loc[i, 'wg_pre'] = 0
            else:
                time_window.loc[i, 'wg_pre'] = 1
    elif time_window.loc[i, 'ethnicitycleaned'] == 'Irish (B)':
        if time_window.loc[i, 'age_period'] == 'teen':
            a = 2.415*int(time_window.loc[i, 'drug_con']) - 0.489*int(time_window.loc[i, 'gender_id']) - 2.655 - 0.432
            if a <= 0:
                time_window.loc[i, 'wg_pre'] = 0
            else:
                time_window.loc[i, 'wg_pre'] = 1
        elif time_window.loc[i, 'age_period'] == 'mid_age':
            a = 2.415*int(time_window.loc[i, 'drug_con']) - 0.489*int(time_window.loc[i, 'gender_id']) - 2.655 + 0.924 - 0.432
            if a <= 0:
                time_window.loc[i, 'wg_pre'] = 0
            else:
                time_window.loc[i, 'wg_pre'] = 1
        else:
            a = 2.415*int(time_window.loc[i, 'drug_con']) - 0.489*int(time_window.loc[i, 'gender_id']) - 2.655 + 0.552 - 0.432
            if a <= 0:
                time_window.loc[i, 'wg_pre'] = 0
            else:
                time_window.loc[i, 'wg_pre'] = 1
    elif time_window.loc[i, 'ethnicitycleaned'] == 'Pakistani (J)':
        if time_window.loc[i, 'age_period'] == 'teen':
            a = 2.415*int(time_window.loc[i, 'drug_con']) - 0.489*int(time_window.loc[i, 'gender_id']) - 2.655 - 0.906
            if a <= 0:
                time_window.loc[i, 'wg_pre'] = 0
            else:
                time_window.loc[i, 'wg_pre'] = 1
        elif time_window.loc[i, 'age_period'] == 'mid_age':
            a = 2.415*int(time_window.loc[i, 'drug_con']) - 0.489*int(time_window.loc[i, 'gender_id']) - 2.655 + 0.924 - 0.906
            if a <= 0:
                time_window.loc[i, 'wg_pre'] = 0
            else:
                time_window.loc[i, 'wg_pre'] = 1
        else:
            a = 2.415*int(time_window.loc[i, 'drug_con']) - 0.489*int(time_window.loc[i, 'gender_id']) - 2.655 + 0.552 - 0.906
            if a <= 0:
                time_window.loc[i, 'wg_pre'] = 0
            else:
                time_window.loc[i, 'wg_pre'] = 1
    else:
        if time_window.loc[i, 'age_period'] == 'teen':
            a = 2.415*int(time_window.loc[i, 'drug_con']) - 0.489*int(time_window.loc[i, 'gender_id']) - 2.655 - 0.185
            if a <= 0:
                time_window.loc[i, 'wg_pre'] = 0
            else:
                time_window.loc[i, 'wg_pre'] = 1
        elif time_window.loc[i, 'age_period'] == 'mid_age':
            a = 2.415*int(time_window.loc[i, 'drug_con']) - 0.489*int(time_window.loc[i, 'gender_id']) - 2.655 + 0.924 - 0.185
            if a <= 0:
                time_window.loc[i, 'wg_pre'] = 0
            else:
                time_window.loc[i, 'wg_pre'] = 1
        else:
            a = 2.415*int(time_window.loc[i, 'drug_con']) - 0.489*int(time_window.loc[i, 'gender_id']) - 2.655 + 0.552 - 0.185
            if a <= 0:
                time_window.loc[i, 'wg_pre'] = 0
            else:
                time_window.loc[i, 'wg_pre'] = 1

# %%
TP = 0
TN = 0
FP = 0
FN = 0
for i in time_window.index:
    if time_window.loc[i, 'all(wg)'] == 0.0 and time_window.loc[i, 'wg_pre'] == 0:
        TP = TP + 1
    elif time_window.loc[i, 'all(wg)'] == 0.0 and time_window.loc[i, 'wg_pre'] == 1:
        FN = FN + 1
    elif time_window.loc[i, 'all(wg)'] == 1.0 and time_window.loc[i, 'wg_pre'] == 0:
        FP = FP + 1
    else:
        TN = TN + 1

# %%
FPF= float(FP)/float(FP+TN)
TPF= float(TP)/float(TP+FN)
rou = float(TP+FN)/float(TP+FP+TN+FN)
tao = rou * TPF + (1 - rou)* FPF
tao
# Out:
# 0.7256632754837423

# %%
print TP
print FP
print TN
print FN
precision = float(TP)/float(TP+FP)
print precision
recall = float(TP)/float(TP+FN)
print recall
f1score = 2*precision*recall/(precision+recall)
print f1score
# Out:
# 28872
# 230
# 327
# 10675
# 0.992096763109
# 0.73006802033
# 0.841148450815

# %%
time_window.insert(0,'wg_pre2',0)

# %%
a = 0
for i in time_window.index:
    if time_window.loc[i, 'ethnicitycleaned'] in ['White and Asian (F)', 'White and Black African (E)', 'White and black Caribbean (D)']:
        a = 2.534*time_window.loc[i, 'drug_con'] - 0.007*int(time_window.loc[i, 'age']) - 0.471*int(time_window.loc[i, 'gender_id']) - 1.751
        if a <= 0:
            time_window.loc[i, 'wg_pre2'] = 0
        else:
            time_window.loc[i, 'wg_pre2'] = 1
    elif time_window.loc[i, 'ethnicitycleaned'] == 'African (N)':
        a = 2.534*int(time_window.loc[i, 'drug_con']) - 0.007*int(time_window.loc[i, 'age']) - 0.471*int(time_window.loc[i, 'gender_id']) - 1.751 + 0.231
        if a <= 0:
            time_window.loc[i, 'wg_pre2'] = 0
        else:
            time_window.loc[i, 'wg_pre2'] = 1
    elif time_window.loc[i, 'ethnicitycleaned'] == 'Bangladeshi (K)':
        a = 2.534*int(time_window.loc[i, 'drug_con']) - 0.007*int(time_window.loc[i, 'age']) - 0.471*int(time_window.loc[i, 'gender_id']) - 1.751 - 0.198
        if a <= 0:
            time_window.loc[i, 'wg_pre2'] = 0
        else:
            time_window.loc[i, 'wg_pre2'] = 1
    elif time_window.loc[i, 'ethnicitycleaned'] == 'British (A)':
        a = 2.534*int(time_window.loc[i, 'drug_con']) - 0.007*int(time_window.loc[i, 'age']) - 0.471*int(time_window.loc[i, 'gender_id']) - 1.751 - 0.357
        if a <= 0:
            time_window.loc[i, 'wg_pre2'] = 0
        else:
            time_window.loc[i, 'wg_pre2'] = 1
    elif time_window.loc[i, 'ethnicitycleaned'] == 'Caribbean (M)':
        a = 2.534*int(time_window.loc[i, 'drug_con']) - 0.007*int(time_window.loc[i, 'age']) - 0.471*int(time_window.loc[i, 'gender_id']) - 1.751 + 0.217
        if a <= 0:
            time_window.loc[i, 'wg_pre2'] = 0
        else:
            time_window.loc[i, 'wg_pre2'] = 1
    elif time_window.loc[i, 'ethnicitycleaned'] == 'Chinese (R)':
        a = 2.534*int(time_window.loc[i, 'drug_con']) - 0.007*int(time_window.loc[i, 'age']) - 0.471*int(time_window.loc[i, 'gender_id']) - 1.751 + 0.284
        if a <= 0:
            time_window.loc[i, 'wg_pre2'] = 0
        else:
            time_window.loc[i, 'wg_pre2'] = 1
    elif time_window.loc[i, 'ethnicitycleaned'] == 'Indian (H)':
        a = 2.534*int(time_window.loc[i, 'drug_con']) - 0.007*int(time_window.loc[i, 'age']) - 0.471*int(time_window.loc[i, 'gender_id']) - 1.751 - 0.443
        if a <= 0:
            time_window.loc[i, 'wg_pre2'] = 0
        else:
            time_window.loc[i, 'wg_pre2'] = 1
    elif time_window.loc[i, 'ethnicitycleaned'] == 'Irish (B)':
        a = 2.534*int(time_window.loc[i, 'drug_con']) - 0.007*int(time_window.loc[i, 'age']) - 0.471*int(time_window.loc[i, 'gender_id']) - 1.751 - 0.384
        if a <= 0:
            time_window.loc[i, 'wg_pre2'] = 0
        else:
            time_window.loc[i, 'wg_pre2'] = 1
    elif time_window.loc[i, 'ethnicitycleaned'] == 'Pakistani (J)':
        a = 2.534*int(time_window.loc[i, 'drug_con']) - 0.007*int(time_window.loc[i, 'age']) - 0.471*int(time_window.loc[i, 'gender_id']) - 1.751 - 0.858
        if a <= 0:
            time_window.loc[i, 'wg_pre2'] = 0
        else:
            time_window.loc[i, 'wg_pre2'] = 1
    else:
        a = 2.534*int(time_window.loc[i, 'drug_con']) - 0.007*int(time_window.loc[i, 'age']) - 0.471*int(time_window.loc[i, 'gender_id']) - 1.751 - 0.159
        if a <= 0:
            time_window.loc[i, 'wg_pre2'] = 0
        else:
            time_window.loc[i, 'wg_pre2'] = 1

# %%
TP = 0
TN = 0
FP = 0
FN = 0
for i in time_window.index:
    if time_window.loc[i, 'all(wg)'] == 0 and time_window.loc[i, 'wg_pre2'] == 0:
        TP = TP + 1
    elif time_window.loc[i, 'all(wg)'] == 0 and time_window.loc[i, 'wg_pre2'] == 1:
        FN = FN + 1
    elif time_window.loc[i, 'all(wg)'] == 1 and time_window.loc[i, 'wg_pre2'] == 0:
        FP = FP + 1
    else:
        TN = TN + 1

# %%
print TP
print FP
print TN
print FN
precision = float(TP)/float(TP+FP)
print precision
recall = float(TP)/float(TP+FN)
print recall
f1score = 2*precision*recall/(precision+recall)
print f1score
# Out:
# 29993
# 236
# 321
# 9554
# 0.992192927321
# 0.758414038992
# 0.859693877551

# %%
time_window.insert(0, 'agr_pre', 0)

# %%
a = 0
for i in time_window.index:
    a = 3.639 * int(time_window.loc[i, 'drug_con']) - 7.039
    if a <= 0:
        time_window.loc[i, 'agr_pre'] = 0
    else:
        time_window.loc[i, 'agr_pre'] = 1

# %%
TP = 0
TN = 0
FP = 0
FN = 0
for i in time_window.index:
    if time_window.loc[i, 'all(agr)'] == 0 and time_window.loc[i, 'agr_pre'] == 0:
        TP = TP + 1
    elif time_window.loc[i, 'all(agr)'] == 0 and time_window.loc[i, 'agr_pre'] == 1:
        FN = FN + 1
    elif time_window.loc[i, 'all(agr)'] == 1 and time_window.loc[i, 'agr_pre'] == 0:
        FP = FP + 1
    else:
        TN = TN + 1

# %%
print TP
print FP
print TN
print FN
precision = float(TP)/float(TP+FP)
print precision
recall = float(TP)/float(TP+FN)
print recall
f1score = 2*precision*recall/(precision+recall)
print f1score
# Out:
# 40069
# 35
# 0
# 0
# 0.9991272691
# 1.0
# 0.999563444052

# %%
time_window.insert(0, 'con_pre', 0)

# %%
a = 0
-

# %%
TP = 0
TN = 0
FP = 0
FN = 0
for i in time_window.index:
    if time_window.loc[i, 'all(con)'] == 0 and time_window.loc[i, 'con_pre'] == 0:
        TP = TP + 1
    elif time_window.loc[i, 'all(con)'] == 0 and time_window.loc[i, 'con_pre'] == 1:
        FN = FN + 1
    elif time_window.loc[i, 'all(con)'] == 1 and time_window.loc[i, 'con_pre'] == 0:
        FP = FP + 1
    else:
        TN = TN + 1

# %%
print TP
print FP
print TN
print FN
precision = float(TP)/float(TP+FP)
print precision
recall = float(TP)/float(TP+FN)
print recall
f1score = 2*precision*recall/(precision+recall)
print f1score
# Out:
# 39518
# 397
# 1
# 188
# 0.990053864462
# 0.995265199214
# 0.992652692129

# %%
time_window.insert(0, 'hyp_pre', 0)

# %%
a = 0
for i in time_window.index:
    if time_window.loc[i, 'age_period'] == 'teen':
        a = 3.584*int(time_window.loc[i, 'drug_con']) + 0.184*int(time_window.loc[i, 'gender_id']) - 6.000
        if a <= 0:
            time_window.loc[i, 'hyp_pre'] = 0
        else:
            time_window.loc[i, 'hyp_pre'] = 1
    elif time_window.loc[i, 'age_period'] == 'mid_age':
        a = 3.584*int(time_window.loc[i, 'drug_con']) + 0.184*int(time_window.loc[i, 'gender_id']) - 6.000 + 1.431
        if a <= 0:
            time_window.loc[i, 'hyp_pre'] = 0
        else:
            time_window.loc[i, 'hyp_pre'] = 1
    else:
        a = 3.584*int(time_window.loc[i, 'drug_con']) + 0.184*int(time_window.loc[i, 'gender_id']) - 6.000 + 1.458
        if a <= 0:
            time_window.loc[i, 'hyp_pre'] = 0
        else:
            time_window.loc[i, 'hyp_pre'] = 1

# %%
TP = 0
TN = 0
FP = 0
FN = 0
for i in time_window.index:
    if time_window.loc[i, 'all(hyp)'] == 0 and time_window.loc[i, 'hyp_pre'] == 0:
        TP = TP + 1
    elif time_window.loc[i, 'all(hyp)'] == 0 and time_window.loc[i, 'hyp_pre'] == 1:
        FN = FN + 1
    elif time_window.loc[i, 'all(hyp)'] == 1 and time_window.loc[i, 'hyp_pre'] == 0:
        FP = FP + 1
    else:
        TN = TN + 1

# %%
print TP
print FP
print TN
print FN
precision = float(TP)/float(TP+FP)
print precision
recall = float(TP)/float(TP+FN)
print recall
f1score = 2*precision*recall/(precision+recall)
print f1score
# Out:
# 39787
# 317
# 0
# 0
# 0.992095551566
# 1.0
# 0.996032093728

# %%
time_window.insert(0, 'noc_pre1', 0)
time_window.insert(0, 'noc_pre2', 0)

# %%
a = 0
for i in time_window.index:
    if time_window.loc[i, 'ethnicitycleaned'] in ['White and Asian (F)', 'White and Black African (E)', 'White and black Caribbean (D)']:
        a = 2.281*time_window.loc[i, 'drug_con'] + 0.029*int(time_window.loc[i, 'age']) - 0.496*int(time_window.loc[i, 'gender_id']) - 4.869
        if a <= 0:
            time_window.loc[i, 'noc_pre1'] = 0
        else:
            time_window.loc[i, 'noc_pre1'] = 1
    elif time_window.loc[i, 'ethnicitycleaned'] == 'African (N)':
        a = 2.281*time_window.loc[i, 'drug_con'] + 0.029*int(time_window.loc[i, 'age']) - 0.496*int(time_window.loc[i, 'gender_id']) - 4.869 -0.100
        if a <= 0:
            time_window.loc[i, 'noc_pre1'] = 0
        else:
            time_window.loc[i, 'noc_pre1'] = 1
    elif time_window.loc[i, 'ethnicitycleaned'] == 'Bangladeshi (K)':
        a = 2.281*time_window.loc[i, 'drug_con'] + 0.029*int(time_window.loc[i, 'age']) - 0.496*int(time_window.loc[i, 'gender_id']) - 4.869 + 0.488
        if a <= 0:
            time_window.loc[i, 'noc_pre1'] = 0
        else:
            time_window.loc[i, 'noc_pre1'] = 1
    elif time_window.loc[i, 'ethnicitycleaned'] == 'British (A)':
        a = 2.281*time_window.loc[i, 'drug_con'] + 0.029*int(time_window.loc[i, 'age']) - 0.496*int(time_window.loc[i, 'gender_id']) - 4.869 - 0.463
        if a <= 0:
            time_window.loc[i, 'noc_pre1'] = 0
        else:
            time_window.loc[i, 'noc_pre1'] = 1
    elif time_window.loc[i, 'ethnicitycleaned'] == 'Caribbean (M)':
        a = 2.281*time_window.loc[i, 'drug_con'] + 0.029*int(time_window.loc[i, 'age']) - 0.496*int(time_window.loc[i, 'gender_id']) - 4.869 - 0.009
        if a <= 0:
            time_window.loc[i, 'noc_pre1'] = 0
        else:
            time_window.loc[i, 'noc_pre1'] = 1
    elif time_window.loc[i, 'ethnicitycleaned'] == 'Chinese (R)':
        a = 2.281*time_window.loc[i, 'drug_con'] + 0.029*int(time_window.loc[i, 'age']) - 0.496*int(time_window.loc[i, 'gender_id']) - 4.869 - 0.624
        if a <= 0:
            time_window.loc[i, 'noc_pre1'] = 0
        else:
            time_window.loc[i, 'noc_pre1'] = 1
    elif time_window.loc[i, 'ethnicitycleaned'] == 'Indian (H)':
        a = 2.281*time_window.loc[i, 'drug_con'] + 0.029*int(time_window.loc[i, 'age']) - 0.496*int(time_window.loc[i, 'gender_id']) - 4.869 - 0.215
        if a <= 0:
            time_window.loc[i, 'noc_pre1'] = 0
        else:
            time_window.loc[i, 'noc_pre1'] = 1
    elif time_window.loc[i, 'ethnicitycleaned'] == 'Irish (B)':
        a = 2.281*time_window.loc[i, 'drug_con'] + 0.029*int(time_window.loc[i, 'age']) - 0.496*int(time_window.loc[i, 'gender_id']) - 4.869 + 0.016
        if a <= 0:
            time_window.loc[i, 'noc_pre1'] = 0
        else:
            time_window.loc[i, 'noc_pre1'] = 1
    elif time_window.loc[i, 'ethnicitycleaned'] == 'Pakistani (J)':
        a = 2.281*time_window.loc[i, 'drug_con'] + 0.029*int(time_window.loc[i, 'age']) - 0.496*int(time_window.loc[i, 'gender_id']) - 4.869 - 1.390
        if a <= 0:
            time_window.loc[i, 'noc_pre1'] = 0
        else:
            time_window.loc[i, 'noc_pre1'] = 1
    else:
        a = 2.281*time_window.loc[i, 'drug_con'] + 0.029*int(time_window.loc[i, 'age']) - 0.496*int(time_window.loc[i, 'gender_id']) - 4.869 - 0.278
        if a <= 0:
            time_window.loc[i, 'noc_pre1'] = 0
        else:
            time_window.loc[i, 'noc_pre1'] = 1

# %%
TP = 0
TN = 0
FP = 0
FN = 0
for i in time_window.index:
    if time_window.loc[i, 'Nocturnal enuresis'] == 0 and time_window.loc[i, 'noc_pre1'] == 0:
        TP = TP + 1
    elif time_window.loc[i, 'Nocturnal enuresis'] == 0 and time_window.loc[i, 'noc_pre1'] == 1:
        FN = FN + 1
    elif time_window.loc[i, 'Nocturnal enuresis'] == 1 and time_window.loc[i, 'noc_pre1'] == 0:
        FP = FP + 1
    else:
        TN = TN + 1

# %%
print TP
print FP
print TN
print FN
precision = float(TP)/float(TP+FP)
print precision
recall = float(TP)/float(TP+FN)
print recall
f1score = 2*precision*recall/(precision+recall)
print f1score
# Out:
# 40038
# 66
# 0
# 0
# 0.998354278875
# 1.0
# 0.99917646178

# %%
a = 0
for i in time_window.index:
    if time_window.loc[i, 'ethnicitycleaned'] in ['White and Asian (F)', 'White and Black African (E)', 'White and black Caribbean (D)']:
        if time_window.loc[i, 'age_period'] == 'teen':
            a = 2.045*int(time_window.loc[i, 'drug_con']) - 0.540*int(time_window.loc[i, 'gender_id']) - 4.633
            if a <= 0:
                time_window.loc[i, 'noc_pre2'] = 0
            else:
                time_window.loc[i, 'noc_pre2'] = 1
        elif time_window.loc[i, 'age_period'] == 'mid_age':
            a = 2.045*int(time_window.loc[i, 'drug_con']) - 0.540*int(time_window.loc[i, 'gender_id']) - 4.633 + 1.155
            if a <= 0:
                time_window.loc[i, 'noc_pre2'] = 0
            else:
                time_window.loc[i, 'noc_pre2'] = 1
        else:
            a = 2.045*int(time_window.loc[i, 'drug_con']) - 0.540*int(time_window.loc[i, 'gender_id']) - 4.633 + 1.752
            if a <= 0:
                time_window.loc[i, 'noc_pre2'] = 0
            else:
                time_window.loc[i, 'noc_pre2'] = 1
    elif time_window.loc[i, 'ethnicitycleaned'] == 'African (N)':
        if time_window.loc[i, 'age_period'] == 'teen':
            a = 2.045*int(time_window.loc[i, 'drug_con']) - 0.540*int(time_window.loc[i, 'gender_id']) - 4.633 - 0.104
            if a <= 0:
                time_window.loc[i, 'noc_pre2'] = 0
            else:
                time_window.loc[i, 'noc_pre2'] = 1
        elif time_window.loc[i, 'age_period'] == 'mid_age':
            a = 2.045*int(time_window.loc[i, 'drug_con']) - 0.540*int(time_window.loc[i, 'gender_id']) - 4.633 + 1.155 - 0.104
            if a <= 0:
                time_window.loc[i, 'noc_pre2'] = 0
            else:
                time_window.loc[i, 'noc_pre2'] = 1
        else:
            a = 2.045*int(time_window.loc[i, 'drug_con']) - 0.540*int(time_window.loc[i, 'gender_id']) - 4.633 + 1.752 - 0.104
            if a <= 0:
                time_window.loc[i, 'noc_pre2'] = 0
            else:
                time_window.loc[i, 'noc_pre2'] = 1
    elif time_window.loc[i, 'ethnicitycleaned'] == 'Bangladeshi (K)':
        if time_window.loc[i, 'age_period'] == 'teen':
            a = 2.045*int(time_window.loc[i, 'drug_con']) - 0.540*int(time_window.loc[i, 'gender_id']) - 4.633 + 0.467
            if a <= 0:
                time_window.loc[i, 'noc_pre2'] = 0
            else:
                time_window.loc[i, 'noc_pre2'] = 1
        elif time_window.loc[i, 'age_period'] == 'mid_age':
            a = 2.045*int(time_window.loc[i, 'drug_con']) - 0.540*int(time_window.loc[i, 'gender_id']) - 4.633 + 1.155 + 0.467
            if a <= 0:
                time_window.loc[i, 'noc_pre2'] = 0
            else:
                time_window.loc[i, 'noc_pre2'] = 1
        else:
            a = 2.045*int(time_window.loc[i, 'drug_con']) - 0.540*int(time_window.loc[i, 'gender_id']) - 4.633 + 1.752 + 0.467
            if a <= 0:
                time_window.loc[i, 'noc_pre2'] = 0
            else:
                time_window.loc[i, 'noc_pre2'] = 1
    elif time_window.loc[i, 'ethnicitycleaned'] == 'British (A)':
        if time_window.loc[i, 'age_period'] == 'teen':
            a = 2.045*int(time_window.loc[i, 'drug_con']) - 0.540*int(time_window.loc[i, 'gender_id']) - 4.633 - 0.391
            if a <= 0:
                time_window.loc[i, 'noc_pre2'] = 0
            else:
                time_window.loc[i, 'noc_pre2'] = 1
        elif time_window.loc[i, 'age_period'] == 'mid_age':
            a = 2.045*int(time_window.loc[i, 'drug_con']) - 0.540*int(time_window.loc[i, 'gender_id']) - 4.633 + 1.155 - 0.391
            if a <= 0:
                time_window.loc[i, 'noc_pre2'] = 0
            else:
                time_window.loc[i, 'noc_pre2'] = 1
        else:
            a = 2.045*int(time_window.loc[i, 'drug_con']) - 0.540*int(time_window.loc[i, 'gender_id']) - 4.633 + 1.752 - 0.391
            if a <= 0:
                time_window.loc[i, 'noc_pre2'] = 0
            else:
                time_window.loc[i, 'noc_pre2'] = 1
    elif time_window.loc[i, 'ethnicitycleaned'] == 'Caribbean (M)':
        if time_window.loc[i, 'age_period'] == 'teen':
            a = 2.045*int(time_window.loc[i, 'drug_con']) - 0.540*int(time_window.loc[i, 'gender_id']) - 4.633 + 0.068
            if a <= 0:
                time_window.loc[i, 'noc_pre2'] = 0
            else:
                time_window.loc[i, 'noc_pre2'] = 1
        elif time_window.loc[i, 'age_period'] == 'mid_age':
            a = 2.045*int(time_window.loc[i, 'drug_con']) - 0.540*int(time_window.loc[i, 'gender_id']) - 4.633 + 1.155 + 0.068
            if a <= 0:
                time_window.loc[i, 'noc_pre2'] = 0
            else:
                time_window.loc[i, 'noc_pre2'] = 1
        else:
            a = 2.045*int(time_window.loc[i, 'drug_con']) - 0.540*int(time_window.loc[i, 'gender_id']) - 4.633 + 1.752 + 0.068
            if a <= 0:
                time_window.loc[i, 'noc_pre2'] = 0
            else:
                time_window.loc[i, 'noc_pre2'] = 1
    elif time_window.loc[i, 'ethnicitycleaned'] == 'Chinese (R)':
        if time_window.loc[i, 'age_period'] == 'teen':
            a = 2.045*int(time_window.loc[i, 'drug_con']) - 0.540*int(time_window.loc[i, 'gender_id']) - 4.633 - 0.626
            if a <= 0:
                time_window.loc[i, 'noc_pre2'] = 0
            else:
                time_window.loc[i, 'noc_pre2'] = 1
        elif time_window.loc[i, 'age_period'] == 'mid_age':
            a = 2.045*int(time_window.loc[i, 'drug_con']) - 0.540*int(time_window.loc[i, 'gender_id']) - 4.633 + 1.155 - 0.626
            if a <= 0:
                time_window.loc[i, 'noc_pre2'] = 0
            else:
                time_window.loc[i, 'noc_pre2'] = 1
        else:
            a = 2.045*int(time_window.loc[i, 'drug_con']) - 0.540*int(time_window.loc[i, 'gender_id']) - 4.633 + 1.752 - 0.626
            if a <= 0:
                time_window.loc[i, 'noc_pre2'] = 0
            else:
                time_window.loc[i, 'noc_pre2'] = 1
    elif time_window.loc[i, 'ethnicitycleaned'] == 'Indian (H)':
        if time_window.loc[i, 'age_period'] == 'teen':
            a = 2.045*int(time_window.loc[i, 'drug_con']) - 0.540*int(time_window.loc[i, 'gender_id']) - 4.633 - 0.096
            if a <= 0:
                time_window.loc[i, 'noc_pre2'] = 0
            else:
                time_window.loc[i, 'noc_pre2'] = 1
        elif time_window.loc[i, 'age_period'] == 'mid_age':
            a = 2.045*int(time_window.loc[i, 'drug_con']) - 0.540*int(time_window.loc[i, 'gender_id']) - 4.633 + 1.155 - 0.096
            if a <= 0:
                time_window.loc[i, 'noc_pre2'] = 0
            else:
                time_window.loc[i, 'noc_pre2'] = 1
        else:
            a = 2.045*int(time_window.loc[i, 'drug_con']) - 0.540*int(time_window.loc[i, 'gender_id']) - 4.633 + 1.752 - 0.096
            if a <= 0:
                time_window.loc[i, 'noc_pre2'] = 0
            else:
                time_window.loc[i, 'noc_pre2'] = 1
    elif time_window.loc[i, 'ethnicitycleaned'] == 'Irish (B)':
        if time_window.loc[i, 'age_period'] == 'teen':
            a = 2.045*int(time_window.loc[i, 'drug_con']) - 0.540*int(time_window.loc[i, 'gender_id']) - 4.633 + 0.123
            if a <= 0:
                time_window.loc[i, 'noc_pre2'] = 0
            else:
                time_window.loc[i, 'noc_pre2'] = 1
        elif time_window.loc[i, 'age_period'] == 'mid_age':
            a = 2.045*int(time_window.loc[i, 'drug_con']) - 0.540*int(time_window.loc[i, 'gender_id']) - 4.633 + 1.155 + 0.123
            if a <= 0:
                time_window.loc[i, 'noc_pre2'] = 0
            else:
                time_window.loc[i, 'noc_pre2'] = 1
        else:
            a = 2.045*int(time_window.loc[i, 'drug_con']) - 0.540*int(time_window.loc[i, 'gender_id']) - 4.633 + 1.752 + 0.123
            if a <= 0:
                time_window.loc[i, 'noc_pre2'] = 0
            else:
                time_window.loc[i, 'noc_pre2'] = 1
    elif time_window.loc[i, 'ethnicitycleaned'] == 'Pakistani (J)':
        if time_window.loc[i, 'age_period'] == 'teen':
            a = 2.045*int(time_window.loc[i, 'drug_con']) - 0.540*int(time_window.loc[i, 'gender_id']) - 4.633 - 1.270
            if a <= 0:
                time_window.loc[i, 'noc_pre2'] = 0
            else:
                time_window.loc[i, 'noc_pre2'] = 1
        elif time_window.loc[i, 'age_period'] == 'mid_age':
            a = 2.045*int(time_window.loc[i, 'drug_con']) - 0.540*int(time_window.loc[i, 'gender_id']) - 4.633 + 1.155 - 1.270
            if a <= 0:
                time_window.loc[i, 'noc_pre2'] = 0
            else:
                time_window.loc[i, 'noc_pre2'] = 1
        else:
            a = 2.045*int(time_window.loc[i, 'drug_con']) - 0.540*int(time_window.loc[i, 'gender_id']) - 4.633 + 1.752 - 1.270
            if a <= 0:
                time_window.loc[i, 'noc_pre2'] = 0
            else:
                time_window.loc[i, 'noc_pre2'] = 1
    else:
        if time_window.loc[i, 'age_period'] == 'teen':
            a = 2.045*int(time_window.loc[i, 'drug_con']) - 0.540*int(time_window.loc[i, 'gender_id']) - 4.633 - 0.262
            if a <= 0:
                time_window.loc[i, 'noc_pre2'] = 0
            else:
                time_window.loc[i, 'noc_pre2'] = 1
        elif time_window.loc[i, 'age_period'] == 'mid_age':
            a = 2.045*int(time_window.loc[i, 'drug_con']) - 0.540*int(time_window.loc[i, 'gender_id']) - 4.633 + 1.155 - 0.262
            if a <= 0:
                time_window.loc[i, 'noc_pre2'] = 0
            else:
                time_window.loc[i, 'noc_pre2'] = 1
        else:
            a = 2.045*int(time_window.loc[i, 'drug_con']) - 0.540*int(time_window.loc[i, 'gender_id']) - 4.633 + 1.752 - 0.262
            if a <= 0:
                time_window.loc[i, 'noc_pre2'] = 0
            else:
                time_window.loc[i, 'noc_pre2'] = 1

# %%
TP = 0
TN = 0
FP = 0
FN = 0
for i in time_window.index:
    if time_window.loc[i, 'Nocturnal enuresis'] == 0 and time_window.loc[i, 'noc_pre2'] == 0:
        TP = TP + 1
    elif time_window.loc[i, 'Nocturnal enuresis'] == 0 and time_window.loc[i, 'noc_pre2'] == 1:
        FN = FN + 1
    elif time_window.loc[i, 'Nocturnal enuresis'] == 1 and time_window.loc[i, 'noc_pre2'] == 0:
        FP = FP + 1
    else:
        TN = TN + 1

# %%
print TP
print FP
print TN
print FN
precision = float(TP)/float(TP+FP)
print precision
recall = float(TP)/float(TP+FN)
print recall
f1score = 2*precision*recall/(precision+recall)
print f1score
# Out:
# 40038
# 66
# 0
# 0
# 0.998354278875
# 1.0
# 0.99917646178

# %%
time_window.insert(0, 'ser_pre', 0)

# %%
a = 0
for i in time_window.index:
    if time_window.loc[i, 'ethnicitycleaned'] in ['White and Asian (F)', 'White and Black African (E)', 'White and black Caribbean (D)']:
        if time_window.loc[i, 'age_period'] == 'teen':
            a = 2.012*int(time_window.loc[i, 'drug_con']) - 1.646
            if a <= 0:
                time_window.loc[i, 'ser_pre'] = 0
            else:
                time_window.loc[i, 'ser_pre'] = 1
        elif time_window.loc[i, 'age_period'] == 'mid_age':
            a = 2.012*int(time_window.loc[i, 'drug_con']) - 1.646 + 0.542
            if a <= 0:
                time_window.loc[i, 'ser_pre'] = 0
            else:
                time_window.loc[i, 'ser_pre'] = 1
        else:
            a = 2.012*int(time_window.loc[i, 'drug_con']) - 1.646 + 0.624
            if a <= 0:
                time_window.loc[i, 'ser_pre'] = 0
            else:
                time_window.loc[i, 'ser_pre'] = 1
    elif time_window.loc[i, 'ethnicitycleaned'] == 'African (N)':
        if time_window.loc[i, 'age_period'] == 'teen':
            a = 2.012*int(time_window.loc[i, 'drug_con']) - 1.646 - 0.006
            if a <= 0:
                time_window.loc[i, 'ser_pre'] = 0
            else:
                time_window.loc[i, 'ser_pre'] = 1
        elif time_window.loc[i, 'age_period'] == 'mid_age':
            a = 2.012*int(time_window.loc[i, 'drug_con']) - 1.646 + 0.542 - 0.006
            if a <= 0:
                time_window.loc[i, 'ser_pre'] = 0
            else:
                time_window.loc[i, 'ser_pre'] = 1
        else:
            a = 2.012*int(time_window.loc[i, 'drug_con']) - 1.646 + 0.624 - 0.006
            if a <= 0:
                time_window.loc[i, 'ser_pre'] = 0
            else:
                time_window.loc[i, 'ser_pre'] = 1
    elif time_window.loc[i, 'ethnicitycleaned'] == 'Bangladeshi (K)':
        if time_window.loc[i, 'age_period'] == 'teen':
            a = 2.012*int(time_window.loc[i, 'drug_con']) - 1.646 - 0.643
            if a <= 0:
                time_window.loc[i, 'ser_pre'] = 0
            else:
                time_window.loc[i, 'ser_pre'] = 1
        elif time_window.loc[i, 'age_period'] == 'mid_age':
            a = 2.012*int(time_window.loc[i, 'drug_con']) - 1.646 + 0.542 - 0.643
            if a <= 0:
                time_window.loc[i, 'ser_pre'] = 0
            else:
                time_window.loc[i, 'ser_pre'] = 1
        else:
            a = 2.012*int(time_window.loc[i, 'drug_con']) - 1.646 + 0.624 - 0.643
            if a <= 0:
                time_window.loc[i, 'ser_pre'] = 0
            else:
                time_window.loc[i, 'ser_pre'] = 1
    elif time_window.loc[i, 'ethnicitycleaned'] == 'British (A)':
        if time_window.loc[i, 'age_period'] == 'teen':
            a = 2.012*int(time_window.loc[i, 'drug_con']) - 1.646 - 0.354
            if a <= 0:
                time_window.loc[i, 'ser_pre'] = 0
            else:
                time_window.loc[i, 'ser_pre'] = 1
        elif time_window.loc[i, 'age_period'] == 'mid_age':
            a = 2.012*int(time_window.loc[i, 'drug_con']) - 1.646 + 0.542 - 0.354
            if a <= 0:
                time_window.loc[i, 'ser_pre'] = 0
            else:
                time_window.loc[i, 'ser_pre'] = 1
        else:
            a = 2.012*int(time_window.loc[i, 'drug_con']) - 1.646 + 0.624 - 0.354
            if a <= 0:
                time_window.loc[i, 'ser_pre'] = 0
            else:
                time_window.loc[i, 'ser_pre'] = 1
    elif time_window.loc[i, 'ethnicitycleaned'] == 'Caribbean (M)':
        if time_window.loc[i, 'age_period'] == 'teen':
            a = 2.012*int(time_window.loc[i, 'drug_con']) - 1.646 + 0.117
            if a <= 0:
                time_window.loc[i, 'ser_pre'] = 0
            else:
                time_window.loc[i, 'ser_pre'] = 1
        elif time_window.loc[i, 'age_period'] == 'mid_age':
            a = 2.012*int(time_window.loc[i, 'drug_con']) - 1.646 + 0.542 + 0.117
            if a <= 0:
                time_window.loc[i, 'ser_pre'] = 0
            else:
                time_window.loc[i, 'ser_pre'] = 1
        else:
            a = 2.012*int(time_window.loc[i, 'drug_con']) - 1.646 + 0.624 + 0.117
            if a <= 0:
                time_window.loc[i, 'ser_pre'] = 0
            else:
                time_window.loc[i, 'ser_pre'] = 1
    elif time_window.loc[i, 'ethnicitycleaned'] == 'Chinese (R)':
        if time_window.loc[i, 'age_period'] == 'teen':
            a = 2.012*int(time_window.loc[i, 'drug_con']) - 1.646 - 0.293
            if a <= 0:
                time_window.loc[i, 'ser_pre'] = 0
            else:
                time_window.loc[i, 'ser_pre'] = 1
        elif time_window.loc[i, 'age_period'] == 'mid_age':
            a = 2.012*int(time_window.loc[i, 'drug_con']) - 1.646 + 0.542 - 0.293
            if a <= 0:
                time_window.loc[i, 'ser_pre'] = 0
            else:
                time_window.loc[i, 'ser_pre'] = 1
        else:
            a = 2.012*int(time_window.loc[i, 'drug_con']) - 1.646 + 0.624 - 0.293
            if a <= 0:
                time_window.loc[i, 'ser_pre'] = 0
            else:
                time_window.loc[i, 'ser_pre'] = 1
    elif time_window.loc[i, 'ethnicitycleaned'] == 'Indian (H)':
        if time_window.loc[i, 'age_period'] == 'teen':
            a = 2.012*int(time_window.loc[i, 'drug_con']) - 1.646 - 0.483
            if a <= 0:
                time_window.loc[i, 'ser_pre'] = 0
            else:
                time_window.loc[i, 'ser_pre'] = 1
        elif time_window.loc[i, 'age_period'] == 'mid_age':
            a = 2.012*int(time_window.loc[i, 'drug_con']) - 1.646 + 0.542 - 0.483
            if a <= 0:
                time_window.loc[i, 'ser_pre'] = 0
            else:
                time_window.loc[i, 'ser_pre'] = 1
        else:
            a = 2.012*int(time_window.loc[i, 'drug_con']) - 1.646 + 0.624 - 0.483
            if a <= 0:
                time_window.loc[i, 'ser_pre'] = 0
            else:
                time_window.loc[i, 'ser_pre'] = 1
    elif time_window.loc[i, 'ethnicitycleaned'] == 'Irish (B)':
        if time_window.loc[i, 'age_period'] == 'teen':
            a = 2.012*int(time_window.loc[i, 'drug_con']) - 1.646 - 0.533
            if a <= 0:
                time_window.loc[i, 'ser_pre'] = 0
            else:
                time_window.loc[i, 'ser_pre'] = 1
        elif time_window.loc[i, 'age_period'] == 'mid_age':
            a = 2.012*int(time_window.loc[i, 'drug_con']) - 1.646 + 0.542 - 0.533
            if a <= 0:
                time_window.loc[i, 'ser_pre'] = 0
            else:
                time_window.loc[i, 'ser_pre'] = 1
        else:
            a = 2.012*int(time_window.loc[i, 'drug_con']) - 1.646 + 0.624 - 0.533
            if a <= 0:
                time_window.loc[i, 'ser_pre'] = 0
            else:
                time_window.loc[i, 'ser_pre'] = 1
    elif time_window.loc[i, 'ethnicitycleaned'] == 'Pakistani (J)':
        if time_window.loc[i, 'age_period'] == 'teen':
            a = 2.012*int(time_window.loc[i, 'drug_con']) - 1.646 - 0.94
            if a <= 0:
                time_window.loc[i, 'ser_pre'] = 0
            else:
                time_window.loc[i, 'ser_pre'] = 1
        elif time_window.loc[i, 'age_period'] == 'mid_age':
            a = 2.012*int(time_window.loc[i, 'drug_con']) - 1.646 + 0.542 - 0.94
            if a <= 0: 
                time_window.loc[i, 'ser_pre'] = 0
            else:
                time_window.loc[i, 'ser_pre'] = 1
        else:
            a = 2.012*int(time_window.loc[i, 'drug_con']) - 1.646 + 0.624 - 0.94
            if a <= 0:
                time_window.loc[i, 'ser_pre'] = 0
            else:
                time_window.loc[i, 'ser_pre'] = 1
    else:
        if time_window.loc[i, 'age_period'] == 'teen':
            a = 2.012*int(time_window.loc[i, 'drug_con']) - 1.646 - 0.192
            if a <= 0:
                time_window.loc[i, 'ser_pre'] = 0
            else:
                time_window.loc[i, 'ser_pre'] = 1
        elif time_window.loc[i, 'age_period'] == 'mid_age':
            a = 2.012*int(time_window.loc[i, 'drug_con']) - 1.646 + 0.542 - 0.192
            if a <= 0:
                time_window.loc[i, 'ser_pre'] = 0
            else:
                time_window.loc[i, 'ser_pre'] = 1
        else:
            a = 2.012*int(time_window.loc[i, 'drug_con']) - 1.646 + 0.624 - 0.192
            if a <= 0:
                time_window.loc[i, 'ser_pre'] = 0
            else:
                time_window.loc[i, 'ser_pre'] = 1

# %%
TP = 0
TN = 0
FP = 0
FN = 0
for i in time_window.index:
    if time_window.loc[i, 'all(sei)'] == 0 and time_window.loc[i, 'ser_pre'] == 0:
        TP = TP + 1
    elif time_window.loc[i, 'all(sei)'] == 0 and time_window.loc[i, 'ser_pre'] == 1:
        FN = FN + 1
    elif time_window.loc[i, 'all(sei)'] == 1 and time_window.loc[i, 'ser_pre'] == 0:
        FP = FP + 1
    else:
        TN = TN + 1

# %%
print TP
print FP
print TN
print FN
precision = float(TP)/float(TP+FP)
print precision
recall = float(TP)/float(TP+FN)
print recall
f1score = 2*precision*recall/(precision+recall)
print f1score
# Out:
# 20512
# 26
# 816
# 18750
# 0.998734053949
# 0.522438999542
# 0.68602006689

# %%
time_window.insert(0, 'pne_pre', 0)

# %%
a = 0
for i in time_window.index:
    if time_window.loc[i, 'all(pne)'] == 1:
        a = a + 1
print a
# Out:
# 51

# %%
a = 0
for i in time_window.index:
    if time_window.loc[i, 'all(ven)'] == 1:
        a = a + 1
print a
# Out:
# 5

# %%
time_window.insert(0, 'hyp_pre', 0)

# %%
import math
tp_hyp = []
tn_hyp = []
fp_hyp = []
fn_hyp = []
f1_hyp = []
tao_hyp = []
b = 50
for j in range(40):
    b = b-1
    c = math.log(float(b)/float(100-b))
    a = 0
    for i in time_window.index:
        if time_window.loc[i, 'age_period'] == 'teen':
            a = 3.584*int(time_window.loc[i, 'drug_con']) + 0.184*int(time_window.loc[i, 'gender_id']) - 6.000
            if a <= c:
                time_window.loc[i, 'hyp_pre'] = 0
            else:
                time_window.loc[i, 'hyp_pre'] = 1
        elif time_window.loc[i, 'age_period'] == 'mid_age':
            a = 3.584*int(time_window.loc[i, 'drug_con']) + 0.184*int(time_window.loc[i, 'gender_id']) - 6.000 + 1.431
            if a <= c:
                time_window.loc[i, 'hyp_pre'] = 0
            else:
                time_window.loc[i, 'hyp_pre'] = 1
        else:
            a = 3.584*int(time_window.loc[i, 'drug_con']) + 0.184*int(time_window.loc[i, 'gender_id']) - 6.000 + 1.458
            if a <= c:
                time_window.loc[i, 'hyp_pre'] = 0
            else:
                time_window.loc[i, 'hyp_pre'] = 1
    print("threshold = %s" % b)
    TP = 0
    TN = 0
    FP = 0
    FN = 0
    for i in time_window.index:
        if time_window.loc[i, 'all(hyp)'] == 0 and time_window.loc[i, 'hyp_pre'] == 0:
            TP = TP + 1
        elif time_window.loc[i, 'all(hyp)'] == 0 and time_window.loc[i, 'hyp_pre'] == 1:
            FN = FN + 1
        elif time_window.loc[i, 'all(hyp)'] == 1 and time_window.loc[i, 'hyp_pre'] == 0:
            FP = FP + 1
        else:
            TN = TN + 1
    tp_hyp.append(TP)
    fp_hyp.append(FP)
    tn_hyp.append(TN)
    fn_hyp.append(FN)
    print TP
    print FP
    print TN
    print FN
    specificity = float(TN)/float(TN+FP)
    print specificity
    recall = float(TP)/float(TP+FN)
    print recall
    f1score = 2*specificity*recall/(specificity+recall)
    f1_hyp.append(f1score)
    print f1score
    FPF= float(FP)/float(FP+TN)
    TPF= float(TP)/float(TP+FN)
    rou = float(TP+FN)/float(TP+FP+TN+FN)
    tao = rou * TPF + (1 - rou)* FPF
    tao_hyp.append(tao)
    print(tao)
# Out:
# threshold = 49
# 39787
# 317
# 0
# 0
# 0.0
# 1.0
# 0.0
# 1.0
# threshold = 48
# 39787
# 317
# 0
# 0
# 0.0
# 1.0
# 0.0
# 1.0
# threshold = 47
# 39787
# 317
# 0
# 0
# 0.0
# 1.0
# 0.0
# 1.0
# threshold = 46
# 39787
# 317
# 0
# 0
# 0.0
# 1.0
# 0.0
# 1.0
# threshold = 45
# 39787
# 317
# 0
# 0
# 0.0
# 1.0
# 0.0
# 1.0
# threshold = 44
# 39787
# 317
# 0
# 0
# 0.0
# 1.0
# 0.0
# 1.0
# threshold = 43
# 39787
# 317
# 0
# 0
# 0.0
# 1.0
# 0.0
# 1.0
# threshold = 42
# 39787
# 317
# 0
# 0
# 0.0
# 1.0
# 0.0
# 1.0
# threshold = 41
# 39787
# 317
# 0
# 0
# 0.0
# 1.0
# 0.0
# 1.0
# threshold = 40
# 39787
# 317
# 0
# 0
# 0.0
# 1.0
# 0.0
# 1.0
# threshold = 39
# 39787
# 317
# 0
# 0
# 0.0
# 1.0
# 0.0
# 1.0
# threshold = 38
# 39787
# 317
# 0
# 0
# 0.0
# 1.0
# 0.0
# 1.0
# threshold = 37
# 39787
# 317
# 0
# 0
# 0.0
# 1.0
# 0.0
# 1.0
# threshold = 36
# 39787
# 317
# 0
# 0
# 0.0
# 1.0
# 0.0
# 1.0
# threshold = 35
# 39787
# 317
# 0
# 0
# 0.0
# 1.0
# 0.0
# 1.0
# threshold = 34
# 39787
# 317
# 0
# 0
# 0.0
# 1.0
# ...

# %%
time_window.insert(0, 'ser_pre', 0)

# %%
b = 50
tp_sei = []
tn_sei = []
fp_sei = []
fn_sei = []
f1_sei = []
tao_sei = []
for j in range(40):
    b = b+1
    c = math.log(float(b)/float(100-b))
    a = 0
    for i in time_window.index:
        if time_window.loc[i, 'ethnicitycleaned'] in ['White and Asian (F)', 'White and Black African (E)', 'White and black Caribbean (D)']:
            if time_window.loc[i, 'age_period'] == 'teen':
                a = 2.012*int(time_window.loc[i, 'drug_con']) - 1.646
                if a <= c:
                    time_window.loc[i, 'ser_pre'] = 0
                else:
                    time_window.loc[i, 'ser_pre'] = 1
            elif time_window.loc[i, 'age_period'] == 'mid_age':
                a = 2.012*int(time_window.loc[i, 'drug_con']) - 1.646 + 0.542
                if a <= c:
                    time_window.loc[i, 'ser_pre'] = 0
                else:
                    time_window.loc[i, 'ser_pre'] = 1
            else:
                a = 2.012*int(time_window.loc[i, 'drug_con']) - 1.646 + 0.624
                if a <= c:
                    time_window.loc[i, 'ser_pre'] = 0
                else:
                    time_window.loc[i, 'ser_pre'] = 1
        elif time_window.loc[i, 'ethnicitycleaned'] == 'African (N)':
            if time_window.loc[i, 'age_period'] == 'teen':
                a = 2.012*int(time_window.loc[i, 'drug_con']) - 1.646 - 0.006
                if a <= c:
                    time_window.loc[i, 'ser_pre'] = 0
                else:
                    time_window.loc[i, 'ser_pre'] = 1
            elif time_window.loc[i, 'age_period'] == 'mid_age':
                a = 2.012*int(time_window.loc[i, 'drug_con']) - 1.646 + 0.542 - 0.006
                if a <= c:
                    time_window.loc[i, 'ser_pre'] = 0
                else:
                    time_window.loc[i, 'ser_pre'] = 1
            else:
                a = 2.012*int(time_window.loc[i, 'drug_con']) - 1.646 + 0.624 - 0.006
                if a <= c:
                    time_window.loc[i, 'ser_pre'] = 0
                else:
                    time_window.loc[i, 'ser_pre'] = 1
        elif time_window.loc[i, 'ethnicitycleaned'] == 'Bangladeshi (K)':
            if time_window.loc[i, 'age_period'] == 'teen':
                a = 2.012*int(time_window.loc[i, 'drug_con']) - 1.646 - 0.643
                if a <= c:
                    time_window.loc[i, 'ser_pre'] = 0
                else:
                    time_window.loc[i, 'ser_pre'] = 1
            elif time_window.loc[i, 'age_period'] == 'mid_age':
                a = 2.012*int(time_window.loc[i, 'drug_con']) - 1.646 + 0.542 - 0.643
                if a <= c:
                    time_window.loc[i, 'ser_pre'] = 0
                else:
                    time_window.loc[i, 'ser_pre'] = 1
            else:
                a = 2.012*int(time_window.loc[i, 'drug_con']) - 1.646 + 0.624 - 0.643
                if a <= c:
                    time_window.loc[i, 'ser_pre'] = 0
                else:
                    time_window.loc[i, 'ser_pre'] = 1
        elif time_window.loc[i, 'ethnicitycleaned'] == 'British (A)':
            if time_window.loc[i, 'age_period'] == 'teen':
                a = 2.012*int(time_window.loc[i, 'drug_con']) - 1.646 - 0.354
                if a <= c:
                    time_window.loc[i, 'ser_pre'] = 0
                else:
                    time_window.loc[i, 'ser_pre'] = 1
            elif time_window.loc[i, 'age_period'] == 'mid_age':
                a = 2.012*int(time_window.loc[i, 'drug_con']) - 1.646 + 0.542 - 0.354
                if a <= c:
                    time_window.loc[i, 'ser_pre'] = 0
                else:
                    time_window.loc[i, 'ser_pre'] = 1
            else:
                a = 2.012*int(time_window.loc[i, 'drug_con']) - 1.646 + 0.624 - 0.354
                if a <= c:
                    time_window.loc[i, 'ser_pre'] = 0
                else:
                    time_window.loc[i, 'ser_pre'] = 1
        elif time_window.loc[i, 'ethnicitycleaned'] == 'Caribbean (M)':
            if time_window.loc[i, 'age_period'] == 'teen':
                a = 2.012*int(time_window.loc[i, 'drug_con']) - 1.646 + 0.117
                if a <= c:
                    time_window.loc[i, 'ser_pre'] = 0
                else:
                    time_window.loc[i, 'ser_pre'] = 1
            elif time_window.loc[i, 'age_period'] == 'mid_age':
                a = 2.012*int(time_window.loc[i, 'drug_con']) - 1.646 + 0.542 + 0.117
                if a <= c:
                    time_window.loc[i, 'ser_pre'] = 0
                else:
                    time_window.loc[i, 'ser_pre'] = 1
            else:
                a = 2.012*int(time_window.loc[i, 'drug_con']) - 1.646 + 0.624 + 0.117
                if a <= c:
                    time_window.loc[i, 'ser_pre'] = 0
                else:
                    time_window.loc[i, 'ser_pre'] = 1
        elif time_window.loc[i, 'ethnicitycleaned'] == 'Chinese (R)':
            if time_window.loc[i, 'age_period'] == 'teen':
                a = 2.012*int(time_window.loc[i, 'drug_con']) - 1.646 - 0.293
                if a <= c:
                    time_window.loc[i, 'ser_pre'] = 0
                else:
                    time_window.loc[i, 'ser_pre'] = 1
            elif time_window.loc[i, 'age_period'] == 'mid_age':
                a = 2.012*int(time_window.loc[i, 'drug_con']) - 1.646 + 0.542 - 0.293
                if a <= c:
                    time_window.loc[i, 'ser_pre'] = 0
                else:
                    time_window.loc[i, 'ser_pre'] = 1
            else:
                a = 2.012*int(time_window.loc[i, 'drug_con']) - 1.646 + 0.624 - 0.293
                if a <= c:
                    time_window.loc[i, 'ser_pre'] = 0
                else:
                    time_window.loc[i, 'ser_pre'] = 1
        elif time_window.loc[i, 'ethnicitycleaned'] == 'Indian (H)':
            if time_window.loc[i, 'age_period'] == 'teen':
                a = 2.012*int(time_window.loc[i, 'drug_con']) - 1.646 - 0.483
                if a <= c:
                    time_window.loc[i, 'ser_pre'] = 0
                else:
                    time_window.loc[i, 'ser_pre'] = 1
            elif time_window.loc[i, 'age_period'] == 'mid_age':
                a = 2.012*int(time_window.loc[i, 'drug_con']) - 1.646 + 0.542 - 0.483
                if a <= c:
                    time_window.loc[i, 'ser_pre'] = 0
                else:
                    time_window.loc[i, 'ser_pre'] = 1
            else:
                a = 2.012*int(time_window.loc[i, 'drug_con']) - 1.646 + 0.624 - 0.483
                if a <= c:
                    time_window.loc[i, 'ser_pre'] = 0
                else:
                    time_window.loc[i, 'ser_pre'] = 1
        elif time_window.loc[i, 'ethnicitycleaned'] == 'Irish (B)':
            if time_window.loc[i, 'age_period'] == 'teen':
                a = 2.012*int(time_window.loc[i, 'drug_con']) - 1.646 - 0.533
                if a <= c:
                    time_window.loc[i, 'ser_pre'] = 0
                else:
                    time_window.loc[i, 'ser_pre'] = 1
            elif time_window.loc[i, 'age_period'] == 'mid_age':
                a = 2.012*int(time_window.loc[i, 'drug_con']) - 1.646 + 0.542 - 0.533
                if a <= c:
                    time_window.loc[i, 'ser_pre'] = 0
                else:
                    time_window.loc[i, 'ser_pre'] = 1
            else:
                a = 2.012*int(time_window.loc[i, 'drug_con']) - 1.646 + 0.624 - 0.533
                if a <= c:
                    time_window.loc[i, 'ser_pre'] = 0
                else:
                    time_window.loc[i, 'ser_pre'] = 1
        elif time_window.loc[i, 'ethnicitycleaned'] == 'Pakistani (J)':
            if time_window.loc[i, 'age_period'] == 'teen':
                a = 2.012*int(time_window.loc[i, 'drug_con']) - 1.646 - 0.94
                if a <= c:
                    time_window.loc[i, 'ser_pre'] = 0
                else:
                    time_window.loc[i, 'ser_pre'] = 1
            elif time_window.loc[i, 'age_period'] == 'mid_age':
                a = 2.012*int(time_window.loc[i, 'drug_con']) - 1.646 + 0.542 - 0.94
                if a <= c: 
                    time_window.loc[i, 'ser_pre'] = 0
                else:
                    time_window.loc[i, 'ser_pre'] = 1
            else:
                a = 2.012*int(time_window.loc[i, 'drug_con']) - 1.646 + 0.624 - 0.94
                if a <= c:
                    time_window.loc[i, 'ser_pre'] = 0
                else:
                    time_window.loc[i, 'ser_pre'] = 1
        else:
            if time_window.loc[i, 'age_period'] == 'teen':
                a = 2.012*int(time_window.loc[i, 'drug_con']) - 1.646 - 0.192
                if a <= c:
                    time_window.loc[i, 'ser_pre'] = 0
                else:
                    time_window.loc[i, 'ser_pre'] = 1
            elif time_window.loc[i, 'age_period'] == 'mid_age':
                a = 2.012*int(time_window.loc[i, 'drug_con']) - 1.646 + 0.542 - 0.192
                if a <= c:
                    time_window.loc[i, 'ser_pre'] = 0
                else:
                    time_window.loc[i, 'ser_pre'] = 1
            else:
                a = 2.012*int(time_window.loc[i, 'drug_con']) - 1.646 + 0.624 - 0.192
                if a <= c:
                    time_window.loc[i, 'ser_pre'] = 0
                else:
                    time_window.loc[i, 'ser_pre'] = 1
    print("threshold = %s" % b)
    TP = 0
    TN = 0
    FP = 0
    FN = 0
    for i in time_window.index:
        if time_window.loc[i, 'all(sei)'] == 0 and time_window.loc[i, 'ser_pre'] == 0:
            TP = TP + 1
        elif time_window.loc[i, 'all(sei)'] == 0 and time_window.loc[i, 'ser_pre'] == 1:
            FN = FN + 1
        elif time_window.loc[i, 'all(sei)'] == 1 and time_window.loc[i, 'ser_pre'] == 0:
            FP = FP + 1
        else:
            TN = TN + 1
    tp_sei.append(TP)
    fp_sei.append(FP)
    tn_sei.append(TN)
    fn_sei.append(FN)
    print TP
    print FP
    print TN
    print FN
    specificity = float(TN)/float(TN+FP)
    print specificity
    recall = float(TP)/float(TP+FN)
    print recall
    f1score = 2*specificity*recall/(specificity+recall)
    f1_sei.append(f1score)
    print f1score
    FPF= float(FP)/float(FP+TN)
    TPF= float(TP)/float(TP+FN)
    rou = float(TP+FN)/float(TP+FP+TN+FN)
    tao = rou * TPF + (1 - rou)* FPF
    tao_sei.append(tao)
    print(tao)
# Out:
# threshold = 51
# 20938
# 50
# 792
# 18324
# 0.940617577197
# 0.533289185472
# 0.680668810659
# 0.523339317774
# threshold = 52
# 20986
# 57
# 785
# 18276
# 0.932304038005
# 0.534511741633
# 0.679468358608
# 0.524710752045
# threshold = 53
# 20986
# 57
# 785
# 18276
# 0.932304038005
# 0.534511741633
# 0.679468358608
# 0.524710752045
# threshold = 54
# 20986
# 57
# 785
# 18276
# 0.932304038005
# 0.534511741633
# 0.679468358608
# 0.524710752045
# threshold = 55
# 21498
# 90
# 752
# 17764
# 0.893111638955
# 0.547552340686
# 0.678888866959
# 0.538300418911
# threshold = 56
# 21498
# 90
# 752
# 17764
# 0.893111638955
# 0.547552340686
# 0.678888866959
# 0.538300418911
# threshold = 57
# 21546
# 95
# 747
# 17716
# 0.887173396675
# 0.548774896847
# 0.678100306873
# 0.539621982845
# threshold = 58
# 21546
# 95
# 747
# 17716
# 0.887173396675
# 0.548774896847
# 0.678100306873
# 0.539621982845
# threshold = 59
# 21764
# 109
# 733
# 17498
# 0.87054631829
# 0.554327339412
# 0.677347948492
# ...

# %%
time_window.insert(0, 'noc_pre1', 0)

# %%
import math
b = 50
for j in range(40):
    b = b-1
    c = math.log(float(b)/float(100-b))
    a = 0
    for i in time_window.index:
        if time_window.loc[i, 'ethnicitycleaned'] in ['White and Asian (F)', 'White and Black African (E)', 'White and black Caribbean (D)']:
            a = 2.281*time_window.loc[i, 'drug_con'] + 0.029*int(time_window.loc[i, 'age']) - 0.496*int(time_window.loc[i, 'gender_id']) - 4.869
            if a <= c:
                time_window.loc[i, 'noc_pre1'] = 0
            else:
                time_window.loc[i, 'noc_pre1'] = 1
        elif time_window.loc[i, 'ethnicitycleaned'] == 'African (N)':
            a = 2.281*time_window.loc[i, 'drug_con'] + 0.029*int(time_window.loc[i, 'age']) - 0.496*int(time_window.loc[i, 'gender_id']) - 4.869 -0.100
            if a <= c:
                time_window.loc[i, 'noc_pre1'] = 0
            else:
                time_window.loc[i, 'noc_pre1'] = 1
        elif time_window.loc[i, 'ethnicitycleaned'] == 'Bangladeshi (K)':
            a = 2.281*time_window.loc[i, 'drug_con'] + 0.029*int(time_window.loc[i, 'age']) - 0.496*int(time_window.loc[i, 'gender_id']) - 4.869 + 0.488
            if a <= c:
                time_window.loc[i, 'noc_pre1'] = 0
            else:
                time_window.loc[i, 'noc_pre1'] = 1
        elif time_window.loc[i, 'ethnicitycleaned'] == 'British (A)':
            a = 2.281*time_window.loc[i, 'drug_con'] + 0.029*int(time_window.loc[i, 'age']) - 0.496*int(time_window.loc[i, 'gender_id']) - 4.869 - 0.463
            if a <= c:
                time_window.loc[i, 'noc_pre1'] = 0
            else:
                time_window.loc[i, 'noc_pre1'] = 1
        elif time_window.loc[i, 'ethnicitycleaned'] == 'Caribbean (M)':
            a = 2.281*time_window.loc[i, 'drug_con'] + 0.029*int(time_window.loc[i, 'age']) - 0.496*int(time_window.loc[i, 'gender_id']) - 4.869 - 0.009
            if a <= c:
                time_window.loc[i, 'noc_pre1'] = 0
            else:
                time_window.loc[i, 'noc_pre1'] = 1
        elif time_window.loc[i, 'ethnicitycleaned'] == 'Chinese (R)':
            a = 2.281*time_window.loc[i, 'drug_con'] + 0.029*int(time_window.loc[i, 'age']) - 0.496*int(time_window.loc[i, 'gender_id']) - 4.869 - 0.624
            if a <= c:
                time_window.loc[i, 'noc_pre1'] = 0
            else:
                time_window.loc[i, 'noc_pre1'] = 1
        elif time_window.loc[i, 'ethnicitycleaned'] == 'Indian (H)':
            a = 2.281*time_window.loc[i, 'drug_con'] + 0.029*int(time_window.loc[i, 'age']) - 0.496*int(time_window.loc[i, 'gender_id']) - 4.869 - 0.215
            if a <= c:
                time_window.loc[i, 'noc_pre1'] = 0
            else:
                time_window.loc[i, 'noc_pre1'] = 1
        elif time_window.loc[i, 'ethnicitycleaned'] == 'Irish (B)':
            a = 2.281*time_window.loc[i, 'drug_con'] + 0.029*int(time_window.loc[i, 'age']) - 0.496*int(time_window.loc[i, 'gender_id']) - 4.869 + 0.016
            if a <= c:
                time_window.loc[i, 'noc_pre1'] = 0
            else:
                time_window.loc[i, 'noc_pre1'] = 1
        elif time_window.loc[i, 'ethnicitycleaned'] == 'Pakistani (J)':
            a = 2.281*time_window.loc[i, 'drug_con'] + 0.029*int(time_window.loc[i, 'age']) - 0.496*int(time_window.loc[i, 'gender_id']) - 4.869 - 1.390
            if a <= c:
                time_window.loc[i, 'noc_pre1'] = 0
            else:
                time_window.loc[i, 'noc_pre1'] = 1
        else:
            a = 2.281*time_window.loc[i, 'drug_con'] + 0.029*int(time_window.loc[i, 'age']) - 0.496*int(time_window.loc[i, 'gender_id']) - 4.869 - 0.278
            if a <= c:
                time_window.loc[i, 'noc_pre1'] = 0
            else:
                time_window.loc[i, 'noc_pre1'] = 1
    print("threshold = %s" % b)
    TP = 0
    TN = 0
    FP = 0
    FN = 0
    for i in time_window.index:
        if time_window.loc[i, 'all(noc)'] == 0 and time_window.loc[i, 'noc_pre1'] == 0:
            TP = TP + 1
        elif time_window.loc[i, 'all(noc)'] == 0 and time_window.loc[i, 'noc_pre1'] == 1:
            FN = FN + 1
        elif time_window.loc[i, 'all(noc)'] == 1 and time_window.loc[i, 'noc_pre1'] == 0:
            FP = FP + 1
        else:
            TN = TN + 1
    print TP
    print FP
    print TN
    print FN
    specificity = float(TN)/float(TN+FP)
    print specificity
    recall = float(TP)/float(TP+FN)
    print recall
    f1score = 2*specificity*recall/(specificity+recall)
    print f1score
# Out:
# threshold = 49
# 39960
# 144
# 0
# 0
# 0.0
# 1.0
# 0.0
# threshold = 48
# 39960
# 144
# 0
# 0
# 0.0
# 1.0
# 0.0
# threshold = 47
# 39959
# 144
# 0
# 1
# 0.0
# 0.999974974975
# 0.0
# threshold = 46
# 39958
# 144
# 0
# 2
# 0.0
# 0.99994994995
# 0.0
# threshold = 45
# 39957
# 144
# 0
# 3
# 0.0
# 0.999924924925
# 0.0
# threshold = 44
# 39955
# 144
# 0
# 5
# 0.0
# 0.999874874875
# 0.0
# threshold = 43
# 39951
# 144
# 0
# 9
# 0.0
# 0.999774774775
# 0.0
# threshold = 42
# 39949
# 144
# 0
# 11
# 0.0
# 0.999724724725
# 0.0
# threshold = 41
# 39947
# 144
# 0
# 13
# 0.0
# 0.999674674675
# 0.0
# threshold = 40
# 39941
# 144
# 0
# 19
# 0.0
# 0.999524524525
# 0.0
# threshold = 39
# 39940
# 144
# 0
# 20
# 0.0
# 0.999499499499
# 0.0
# threshold = 38
# 39933
# 144
# 0
# 27
# 0.0
# 0.999324324324
# 0.0
# threshold = 37
# 39927
# 144
# 0
# 33
# 0.0
# 0.999174174174
# 0.0
# threshold = 36
# 39921
# 144
# 0
# 39
# 0.0
# 0.999024024024
# 0.0
# threshold = 35
# 39908
# 144
# 0
# 52
# 0.0
# 0.998698698699
# ...

# %%
data2 = pd.read_csv("data2.csv")

# %%
data3 = data2[data2['Agranulocytosis(2)'] == 1.0]

# %%
group1 =data3.groupby(['age']).count()

# %%
group1.index
# Out:
# Float64Index([  4.0,   5.0,   6.0,   7.0,   8.0,   9.0,  10.0,  11.0,  12.0,
#                13.0,
#               ...
#               100.0, 101.0, 102.0, 103.0, 104.0, 105.0, 106.0, 107.0, 108.0,
#               112.0],
#              dtype='float64', name=u'age', length=106)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.bar(group1.index, group1.brcid)
plt.show()

# %%
b = 50
tp_con = []
tn_con = []
fp_con = []
fn_con = []
f1_con = []
for j in range(40):
    b = b-1
    c = math.log(float(b)/float(100-b))
    a = 0
    for i in time_window.index:
        if time_window.loc[i, 'ethnicitycleaned'] in ['White and Asian (F)', 'White and Black African (E)', 'White and black Caribbean (D)']:
            a = 2.356*time_window.loc[i, 'drug_con'] + 0.017*int(time_window.loc[i, 'age']) - 0.345*int(time_window.loc[i, 'gender_id']) - 3.240
            if a <= c:
                time_window.loc[i, 'con_pre'] = 0
            else:
                time_window.loc[i, 'con_pre'] = 1
        elif time_window.loc[i, 'ethnicitycleaned'] == 'African (N)':
            a = 2.356*time_window.loc[i, 'drug_con'] + 0.017*int(time_window.loc[i, 'age']) - 0.345*int(time_window.loc[i, 'gender_id']) - 3.240 - 0.141
            if a <= c:
                time_window.loc[i, 'con_pre'] = 0
            else:
                time_window.loc[i, 'con_pre'] = 1
        elif time_window.loc[i, 'ethnicitycleaned'] == 'Bangladeshi (K)':
            a = 2.356*time_window.loc[i, 'drug_con'] + 0.017*int(time_window.loc[i, 'age']) - 0.345*int(time_window.loc[i, 'gender_id']) - 3.240 + 0.289
            if a <= c:
                time_window.loc[i, 'con_pre'] = 0
            else:
                time_window.loc[i, 'con_pre'] = 1
        elif time_window.loc[i, 'ethnicitycleaned'] == 'British (A)':
            a = 2.356*time_window.loc[i, 'drug_con'] + 0.017*int(time_window.loc[i, 'age']) - 0.345*int(time_window.loc[i, 'gender_id']) - 3.240 - 0.417
            if a <= c:
                time_window.loc[i, 'con_pre'] = 0
            else:
                time_window.loc[i, 'con_pre'] = 1
        elif time_window.loc[i, 'ethnicitycleaned'] == 'Caribbean (M)':
            a = 2.356*time_window.loc[i, 'drug_con'] + 0.017*int(time_window.loc[i, 'age']) - 0.345*int(time_window.loc[i, 'gender_id']) - 3.240 - 0.168
            if a <= c:
                time_window.loc[i, 'con_pre'] = 0
            else:
                time_window.loc[i, 'con_pre'] = 1
        elif time_window.loc[i, 'ethnicitycleaned'] == 'Chinese (R)':
            a = 2.356*time_window.loc[i, 'drug_con'] + 0.017*int(time_window.loc[i, 'age']) - 0.345*int(time_window.loc[i, 'gender_id']) - 3.240 + 0.109
            if a <= c:
                time_window.loc[i, 'con_pre'] = 0
            else:
                time_window.loc[i, 'con_pre'] = 1
        elif time_window.loc[i, 'ethnicitycleaned'] == 'Indian (H)':
            a = 2.356*time_window.loc[i, 'drug_con'] + 0.017*int(time_window.loc[i, 'age']) - 0.345*int(time_window.loc[i, 'gender_id']) - 3.240 - 0.626
            if a <= c:
                time_window.loc[i, 'con_pre'] = 0
            else:
                time_window.loc[i, 'con_pre'] = 1
        elif time_window.loc[i, 'ethnicitycleaned'] == 'Irish (B)':
            a = 2.356*time_window.loc[i, 'drug_con'] + 0.017*int(time_window.loc[i, 'age']) - 0.345*int(time_window.loc[i, 'gender_id']) - 3.240 - 0.208
            if a <= c:
                time_window.loc[i, 'con_pre'] = 0
            else:
                time_window.loc[i, 'con_pre'] = 1
        elif time_window.loc[i, 'ethnicitycleaned'] == 'Pakistani (J)':
            a = 2.356*time_window.loc[i, 'drug_con'] + 0.017*int(time_window.loc[i, 'age']) - 0.345*int(time_window.loc[i, 'gender_id']) - 3.240 - 0.333
            if a <= c:
                time_window.loc[i, 'con_pre'] = 0
            else:
                time_window.loc[i, 'con_pre'] = 1
        else:
            a = 2.356*time_window.loc[i, 'drug_con'] + 0.017*int(time_window.loc[i, 'age']) - 0.345*int(time_window.loc[i, 'gender_id']) - 3.240 - 0.336
            if a <= c:
                time_window.loc[i, 'con_pre'] = 0
            else:
                time_window.loc[i, 'con_pre'] = 1
    print("threshold = %s" % b)
    TP = 0
    TN = 0
    FP = 0
    FN = 0
    for i in time_window.index:
        if time_window.loc[i, 'all(con)'] == 0 and time_window.loc[i, 'con_pre'] == 0:
            TP = TP + 1
        elif time_window.loc[i, 'all(con)'] == 0 and time_window.loc[i, 'con_pre'] == 1:
            FN = FN + 1
        elif time_window.loc[i, 'all(con)'] == 1 and time_window.loc[i, 'con_pre'] == 0:
            FP = FP + 1
        else:
            TN = TN + 1
    print TP
    print FP
    print TN
    print FN
    specificity = float(TN)/float(TN+FP)
    print specificity
    recall = float(TP)/float(TP+FN)
    print recall
    f1score = 2*specificity*recall/(specificity+recall)
    print f1score
# Out:
# threshold = 49
# 39467
# 393
# 5
# 239
# 0.0125628140704
# 0.993980758576
# 0.0248120315878
# threshold = 48
# 39379
# 391
# 7
# 327
# 0.0175879396985
# 0.991764468846
# 0.0345629406053
# threshold = 47
# 39283
# 386
# 12
# 423
# 0.0301507537688
# 0.989346698232
# 0.0585181427023
# threshold = 46
# 39147
# 380
# 18
# 559
# 0.0452261306533
# 0.985921523195
# 0.0864850256032
# threshold = 45
# 38932
# 372
# 26
# 774
# 0.0653266331658
# 0.980506724425
# 0.122492178392
# threshold = 44
# 38659
# 362
# 36
# 1047
# 0.0904522613065
# 0.973631189241
# 0.165526759579
# threshold = 43
# 38345
# 349
# 49
# 1361
# 0.123115577889
# 0.965723064524
# 0.218389664986
# threshold = 42
# 37985
# 341
# 57
# 1721
# 0.143216080402
# 0.956656424722
# 0.249135391242
# threshold = 41
# 37583
# 333
# 65
# 2123
# 0.163316582915
# 0.946532010276
# 0.278568400205
# threshold = 40
# 37068
# 319
# 79
# 2638
# 0.198492462312
# 0.933561678336
# 0.327378257981
# threshold = 39
# 36465
# 304
# 94
# 3241
# ...

# %%
b = 50
for j in range(40):
    b = b-1
    c = math.log(float(b)/float(100-b))
    a = 0
    for i in time_window.index:
        if time_window.loc[i, 'ethnicitycleaned'] in ['White and Asian (F)', 'White and Black African (E)', 'White and black Caribbean (D)']:
            a = 2.534*time_window.loc[i, 'drug_con'] - 0.007*int(time_window.loc[i, 'age']) - 0.471*int(time_window.loc[i, 'gender_id']) - 1.751
            if a <= c:
                time_window.loc[i, 'wg_pre2'] = 0
            else:
                time_window.loc[i, 'wg_pre2'] = 1
        elif time_window.loc[i, 'ethnicitycleaned'] == 'African (N)':
            a = 2.534*int(time_window.loc[i, 'drug_con']) - 0.007*int(time_window.loc[i, 'age']) - 0.471*int(time_window.loc[i, 'gender_id']) - 1.751 + 0.231
            if a <= c:
                time_window.loc[i, 'wg_pre2'] = 0
            else:
                time_window.loc[i, 'wg_pre2'] = 1
        elif time_window.loc[i, 'ethnicitycleaned'] == 'Bangladeshi (K)':
            a = 2.534*int(time_window.loc[i, 'drug_con']) - 0.007*int(time_window.loc[i, 'age']) - 0.471*int(time_window.loc[i, 'gender_id']) - 1.751 - 0.198
            if a <= c:
                time_window.loc[i, 'wg_pre2'] = 0
            else:
                time_window.loc[i, 'wg_pre2'] = 1
        elif time_window.loc[i, 'ethnicitycleaned'] == 'British (A)':
            a = 2.534*int(time_window.loc[i, 'drug_con']) - 0.007*int(time_window.loc[i, 'age']) - 0.471*int(time_window.loc[i, 'gender_id']) - 1.751 - 0.357
            if a <= c:
                time_window.loc[i, 'wg_pre2'] = 0
            else:
                time_window.loc[i, 'wg_pre2'] = 1
        elif time_window.loc[i, 'ethnicitycleaned'] == 'Caribbean (M)':
            a = 2.534*int(time_window.loc[i, 'drug_con']) - 0.007*int(time_window.loc[i, 'age']) - 0.471*int(time_window.loc[i, 'gender_id']) - 1.751 + 0.217
            if a <= c:
                time_window.loc[i, 'wg_pre2'] = 0
            else:
                time_window.loc[i, 'wg_pre2'] = 1
        elif time_window.loc[i, 'ethnicitycleaned'] == 'Chinese (R)':
            a = 2.534*int(time_window.loc[i, 'drug_con']) - 0.007*int(time_window.loc[i, 'age']) - 0.471*int(time_window.loc[i, 'gender_id']) - 1.751 + 0.284
            if a <= c:
                time_window.loc[i, 'wg_pre2'] = 0
            else:
                time_window.loc[i, 'wg_pre2'] = 1
        elif time_window.loc[i, 'ethnicitycleaned'] == 'Indian (H)':
            a = 2.534*int(time_window.loc[i, 'drug_con']) - 0.007*int(time_window.loc[i, 'age']) - 0.471*int(time_window.loc[i, 'gender_id']) - 1.751 - 0.443
            if a <= c:
                time_window.loc[i, 'wg_pre2'] = 0
            else:
                time_window.loc[i, 'wg_pre2'] = 1
        elif time_window.loc[i, 'ethnicitycleaned'] == 'Irish (B)':
            a = 2.534*int(time_window.loc[i, 'drug_con']) - 0.007*int(time_window.loc[i, 'age']) - 0.471*int(time_window.loc[i, 'gender_id']) - 1.751 - 0.384
            if a <= c:
                time_window.loc[i, 'wg_pre2'] = 0
            else:
                time_window.loc[i, 'wg_pre2'] = 1
        elif time_window.loc[i, 'ethnicitycleaned'] == 'Pakistani (J)':
            a = 2.534*int(time_window.loc[i, 'drug_con']) - 0.007*int(time_window.loc[i, 'age']) - 0.471*int(time_window.loc[i, 'gender_id']) - 1.751 - 0.858
            if a <= c:
                time_window.loc[i, 'wg_pre2'] = 0
            else:
                time_window.loc[i, 'wg_pre2'] = 1
        else:
            a = 2.534*int(time_window.loc[i, 'drug_con']) - 0.007*int(time_window.loc[i, 'age']) - 0.471*int(time_window.loc[i, 'gender_id']) - 1.751 - 0.159
            if a <= c:
                time_window.loc[i, 'wg_pre2'] = 0
            else:
                time_window.loc[i, 'wg_pre2'] = 1
    print("threshold = %s" % b)
    TP = 0
    TN = 0
    FP = 0
    FN = 0
    for i in time_window.index:
        if time_window.loc[i, 'all(wg)'] == 0 and time_window.loc[i, 'wg_pre2'] == 0:
            TP = TP + 1
        elif time_window.loc[i, 'all(wg)'] == 0 and time_window.loc[i, 'wg_pre2'] == 1:
            FN = FN + 1
        elif time_window.loc[i, 'all(wg)'] == 1 and time_window.loc[i, 'wg_pre2'] == 0:
            FP = FP + 1
        else:
            TN = TN + 1
    print TP
    print FP
    print TN
    print FN
    specificity = float(TN)/float(TN+FP)
    print specificity
    recall = float(TP)/float(TP+FN)
    print recall
    f1score = 2*specificity*recall/(specificity+recall)
    print f1score
# Out:
# threshold = 49
# 29259
# 214
# 343
# 10288
# 0.615798922801
# 0.739853844792
# 0.672150290317
# threshold = 48
# 28545
# 183
# 374
# 11002
# 0.671454219031
# 0.721799377955
# 0.695717188415
# threshold = 47
# 27798
# 157
# 400
# 11749
# 0.718132854578
# 0.70291046097
# 0.710440125683
# threshold = 46
# 27198
# 150
# 407
# 12349
# 0.730700179533
# 0.687738640099
# 0.708568802316
# threshold = 45
# 26514
# 134
# 423
# 13033
# 0.759425493716
# 0.670442764306
# 0.712165368292
# threshold = 44
# 25654
# 113
# 444
# 13893
# 0.797127468582
# 0.648696487723
# 0.715292877645
# threshold = 43
# 24894
# 98
# 459
# 14653
# 0.824057450628
# 0.629478847953
# 0.713744452306
# threshold = 42
# 23736
# 74
# 483
# 15811
# 0.867145421903
# 0.600197233671
# 0.709388882603
# threshold = 41
# 22578
# 43
# 514
# 16969
# 0.922800718133
# 0.57091561939
# 0.705410164342
# threshold = 40
# 21760
# 36
# 521
# 17787
# 0.935368043088
# 0.550231370268
# 0.692877010352
# threshold = 39
# 21083
# 27
# 530
# 18464
# ...
